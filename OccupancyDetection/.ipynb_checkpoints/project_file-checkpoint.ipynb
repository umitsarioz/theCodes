# %% [markdown]
# # 1. Import Libraries

# %%
import numpy as np  # for matrices, vector operations
import pandas as pd  # for data frame operations
from sklearn.preprocessing import StandardScaler # for preprocessing, just scale data
import os # for file operations

# Data visualization
import seaborn as sns
import matplotlib.pyplot as plt

# For training, NN.
from keras.models import Sequential
from keras.layers.core import Dense
from keras.optimizers import Adam

# %% [markdown]
# ## 2. Load Datasets

# %%
current_dir = os.getcwd()
datasets_dir = current_dir + '/dataset'

ds_train = datasets_dir +'/train.csv'
ds_dev = datasets_dir + '/dev.csv'
ds_test = datasets_dir + '/test.csv'

# %%
def load_dataset(dataset):
    '''
    Load dataset as pandas dataframe.
    '''
    dataset_frame = pd.read_csv(dataset)
    print(f"{dataset.split(sep='/')[-1]} is loaded")
    return dataset_frame

# %%
# Load datasets as dataframe
df_train = load_dataset(ds_train)
df_dev = load_dataset(ds_dev)
df_test = load_dataset(ds_test)
# Out:
# train.csv is loaded
# dev.csv is loaded
# test.csv is loaded

# %% [markdown]
# ## 3. Data Analysis

# %%
df_train.head() # look first 5 row.
# Out:
#                   date  Temperature  Humidity  Light     CO2  HumidityRatio  \
# 0  2015-02-04 17:51:00        23.18   27.2720  426.0  721.25       0.004793
# 1  2015-02-04 17:51:59        23.15   27.2675  429.5  714.00       0.004783
# 2  2015-02-04 17:53:00          NaN   27.2450  426.0     NaN       0.004779
# 3  2015-02-04 17:54:00        23.15   27.2000  426.0  708.25       0.004772
# 4  2015-02-04 17:55:00          NaN   27.2000  426.0     NaN       0.004757
#
#    Occupancy
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1

# %%
# We can see that there are NaN values in df_train so let's look info about datasets.

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8143 entries, 0 to 8142
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           8143 non-null   object
#  1   Temperature    7763 non-null   float64
#  2   Humidity       8143 non-null   float64
#  3   Light          8143 non-null   float64
#  4   CO2            7633 non-null   float64
#  5   HumidityRatio  8143 non-null   float64
#  6   Occupancy      8143 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 445.4+ KB

# %%
df_dev.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2665 entries, 0 to 2664
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           2665 non-null   object
#  1   Temperature    2665 non-null   float64
#  2   Humidity       2665 non-null   float64
#  3   Light          2665 non-null   float64
#  4   CO2            2665 non-null   float64
#  5   HumidityRatio  2665 non-null   float64
#  6   Occupancy      2665 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 145.9+ KB

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9752 entries, 0 to 9751
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           9752 non-null   object
#  1   Temperature    9752 non-null   float64
#  2   Humidity       9752 non-null   float64
#  3   Light          9752 non-null   float64
#  4   CO2            9752 non-null   float64
#  5   HumidityRatio  9752 non-null   float64
#  6   Occupancy      9752 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 533.4+ KB

# %%
'''
# Train dataset : 
There are 8143 rows and 6 columns. It's mean we have 6 features which 5 of them is using to predict occupancy room.
Date feature's type is Object and others is numerical.

# Dev dataset : 
There are 2665 rows and 6 columns. It's mean we have 6 features which 5 of them is using to predict occupancy room.
Date feature's type is Object and others is numerical.

# Test dataset : 
There are 9752 rows and 6 columns. It's mean we have 6 features which 5 of them is using to predict occupancy room.
Date feature's type is Object and others is numerical.
'''
# Out:
# "\n# Train dataset : \nThere are 8143 rows and 6 columns. It's mean we have 6 features which 5 of them is using to predict occupancy room.\nDate feature's type is Object and others is numerical.\n\n# Dev dataset : \nThere are 2665 rows and 6 columns. It's mean we have 6 features which 5 of them is using to predict occupancy room.\nDate feature's type is Object and others is numerical.\n\n# Test dataset : \nThere are 9752 rows and 6 columns. It's mean we have 6 features which 5 of them is using to predict occupancy room.\nDate feature's type is Object and others is numerical.\n"

# %%
def isMissingValue(df,name):
  '''
  Input: an original data frame.
  Output : return yes or not answer.And if yes shows which class has nan values and their numbers.
  '''
  na_checker = df.isna().any().sum()
  if na_checker > 0:
    print("Are there any missing/NaN values in ",name,"set? : Yes")
    print("\n\tCounts")
    print(df.isna().sum())
  else:
    print("Are there any missing/NaN values in ",name,"set? : No ")

# %%
isMissingValue(df_train,'Train')
isMissingValue(df_dev,'Dev')
isMissingValue(df_test,'Test')
# Out:
# Are there any missing/NaN values in  Train set? : Yes
#
# 	Counts
# date               0
# Temperature      380
# Humidity           0
# Light              0
# CO2              510
# HumidityRatio      0
# Occupancy          0
# dtype: int64
# Are there any missing/NaN values in  Dev set? : No
# Are there any missing/NaN values in  Test set? : No

# %%
'''
We can see there are missing values in train dataset. Other datasets have not missing values.
So let's fill missing values in train dataset.
'''
# Out:
# "\nWe can see there are missing values in train dataset. Other datasets have not missing values.\nSo let's fill missing values in train dataset.\n"

# %% [markdown]
# ## 4. Data Preprocessing

# %%
def divide_dataset(dataset,cols_X,col_y):
    '''
    This function split our dataset as X and y. 
    Input : the dataset path.
    '''
    X = pd.read_csv(dataset,sep=',',usecols = cols_X)
    y = pd.read_csv(dataset,sep=',',usecols = col_y)
    print(f"{dataset.split(sep='/')[-1]} is splitted as X and y")
    return X,y

cols_X = ['date','Temperature','Humidity','Light','CO2','HumidityRatio']
col_y = ['Occupancy']

df_train_X,df_train_y = divide_dataset(ds_train,cols_X,col_y)
df_dev_X,df_dev_y = divide_dataset(ds_dev,cols_X,col_y)
df_test_X,df_test_y = divide_dataset(ds_test,cols_X,col_y)
# Out:
# train.csv is splitted as X and y
# dev.csv is splitted as X and y
# test.csv is splitted as X and y

# %%
def fillAsMean(df,missing_features):
    '''
    Inputs:
    df -- A dataframe has missing values
    missing_features -- column names of the data frame
    
    Outputs:
    return dataframe has no missing values , it's mean filled dataframe.
    '''
    size = len(missing_features)
    for i in range(size):
      feature_name = missing_features[i]
      avg = np.mean(df.get(feature_name)) 
      df[feature_name] = df[feature_name].fillna(avg)
      print(f'Missing values are filled with average of {feature_name} columns.')
    return df

# %%
missing_features = ['Temperature','CO2']

df_train_X = fillAsMean(df_train_X,missing_features)
# Out:
# Missing values are filled with average of Temperature columns.
# Missing values are filled with average of CO2 columns.

# %%
df_train_X.isna().any()
# Out:
# date             False
# Temperature      False
# Humidity         False
# Light            False
# CO2              False
# HumidityRatio    False
# dtype: bool

# %%
df_dev_X.describe()
# Out:
#        Temperature     Humidity        Light          CO2  HumidityRatio
# count  2665.000000  2665.000000  2665.000000  2665.000000    2665.000000
# mean     21.433876    25.353937   193.227556   717.906470       0.004027
# std       1.028024     2.436842   250.210906   292.681718       0.000611
# min      20.200000    22.100000     0.000000   427.500000       0.003303
# 25%      20.650000    23.260000     0.000000   466.000000       0.003529
# 50%      20.890000    25.000000     0.000000   580.500000       0.003815
# 75%      22.356667    26.856667   442.500000   956.333333       0.004532
# max      24.408333    31.472500  1697.250000  1402.250000       0.005378

# %%
df_test_X.describe()
# Out:
#        Temperature     Humidity        Light          CO2  HumidityRatio
# count  9752.000000  9752.000000  9752.000000  9752.000000    9752.000000
# mean     21.001768    29.891910   123.067930   753.224832       0.004589
# std       1.020693     3.952844   208.221275   297.096114       0.000531
# min      19.500000    21.865000     0.000000   484.666667       0.003275
# 25%      20.290000    26.642083     0.000000   542.312500       0.004196
# 50%      20.790000    30.200000     0.000000   639.000000       0.004593
# 75%      21.533333    32.700000   208.250000   831.125000       0.004998
# max      24.390000    39.500000  1581.000000  2076.500000       0.005769

# %%
'''
Above, we can see min,max,mean,std and count values.Also,We can't see date column above.
Because Date column's type is Object. If we trained our model, 
this column will be used as training . 
So we should convert datetime to numeric.
'''
df_train_X.dtypes
# Out:
# date              object
# Temperature      float64
# Humidity         float64
# Light            float64
# CO2              float64
# HumidityRatio    float64
# dtype: object

# %%
def dateTimeConverter(df):
  '''
  Input: df -- a dataframe will be converted to datetime. 
  Output: return df -- the dataframe's datetime column is converted  as numeric.
  '''
  try:
    df["date"] = pd.to_datetime(df["date"])
    df["date"] = pd.Float64Index(df["date"])
    print("Date time converting process is successed.")
  except:
    print("Exception Occured Step: Datetime Convert!")
  return df

# %%
df_train_X = dateTimeConverter(df_train_X)
df_dev_X = dateTimeConverter(df_dev_X)
df_test_X = dateTimeConverter(df_test_X)
# Out:
# Date time converting process is successed.
# Date time converting process is successed.
# Date time converting process is successed.

# %%
df_train_X.dtypes
# Out:
# date             float64
# Temperature      float64
# Humidity         float64
# Light            float64
# CO2              float64
# HumidityRatio    float64
# dtype: object

# %%
def trundle(df,features):
  '''
  Inputs : df -- a dataframe has values will rounded.
          feature_name -- column name has values will rounded.
  Output: return df -- a dataframe has rounded values.
  '''
  for feature_name in features:
    df[feature_name] = round(df[feature_name],5)
    print(feature_name," Rounded operation is successful !")
  print("\n\n")
  return df

# %%
features = df_train_X.columns
df_train_X = trundle(df_train_X,features)
df_dev_X = trundle(df_dev_X,features)
df_test_X = trundle(df_test_X,features)
# Out:
# date  Rounded operation is successful !
# Temperature  Rounded operation is successful !
# Humidity  Rounded operation is successful !
# Light  Rounded operation is successful !
# CO2  Rounded operation is successful !
# HumidityRatio  Rounded operation is successful !
#
#
#
# date  Rounded operation is successful !
# Temperature  Rounded operation is successful !
# Humidity  Rounded operation is successful !
# Light  Rounded operation is successful !
# CO2  Rounded operation is successful !
# HumidityRatio  Rounded operation is successful !
#
#
#
# date  Rounded operation is successful !
# Temperature  Rounded operation is successful !
# Humidity  Rounded operation is successful !
# Light  Rounded operation is successful !
# CO2  Rounded operation is successful !
# HumidityRatio  Rounded operation is successful !

# %%
df_train_X
# Out:
#               date  Temperature  Humidity  Light        CO2  HumidityRatio
# 0     1.423072e+18     23.18000   27.2720  426.0  721.25000        0.00479
# 1     1.423072e+18     23.15000   27.2675  429.5  714.00000        0.00478
# 2     1.423072e+18     20.57617   27.2450  426.0  604.03209        0.00478
# 3     1.423072e+18     23.15000   27.2000  426.0  708.25000        0.00477
# 4     1.423072e+18     20.57617   27.2000  426.0  604.03209        0.00476
# ...            ...          ...       ...    ...        ...            ...
# 8138  1.423561e+18     21.05000   36.0975  433.0  787.25000        0.00558
# 8139  1.423561e+18     21.05000   35.9950  433.0  789.50000        0.00556
# 8140  1.423561e+18     21.10000   36.0950  433.0  798.50000        0.00560
# 8141  1.423561e+18     21.10000   36.2600  433.0  820.33333        0.00562
# 8142  1.423561e+18     21.10000   36.2000  447.0  821.00000        0.00561
#
# [8143 rows x 6 columns]

# %%
'''
add functions is taken same input and return same output.
Input : df -- our real dataframe.
Output : return another dataframe. The dataframe has new feature.
'''
def add_TempLight(df):
  df_has_new_feature = df
  df_has_new_feature.columns = df.columns
  try:
    df_has_new_feature['Temp*Light']=df_has_new_feature['Temperature'] * (df_has_new_feature)["Light"]
    print("Temp x Ligth feature is added !")
  except:
    print("Exception occured: Co2 x HR feature is NOT added !")
  return (df_has_new_feature)

def add_CO2Temp(df):
  df_has_new_feature = df
  df_has_new_feature.columns = df.columns
  try:
    df_has_new_feature['CO2*Temp']=df_has_new_feature['CO2'] * (df_has_new_feature)["Temperature"]
    print("Co2 x Temperature feature is added !")
  except:
    print("CO2 x Temperature feature is NOT added !")
  return (df_has_new_feature)

# %%
# Add new Features All Datasets.
print("Train-Set")
train_X = add_TempLight(df_train_X)
train_X = add_CO2Temp(df_train_X)
print("\nDev-Set")
dev_X = add_TempLight(df_dev_X)
dev_X = add_CO2Temp(df_dev_X)
print("\nTest-Set")
test_X = add_TempLight(df_test_X)
test_X = add_CO2Temp(df_test_X)
# Out:
# Train-Set
# Temp x Ligth feature is added !
# Co2 x Temperature feature is added !
#
# Dev-Set
# Temp x Ligth feature is added !
# Co2 x Temperature feature is added !
#
# Test-Set
# Temp x Ligth feature is added !
# Co2 x Temperature feature is added !

# %%
'''
Scaling - I will use StandardScaler.StandardScaler is using Z-Score , 
z = (x-u) /s
x is our actual data. 
u is our data's mean. If with_mean = False will be 0(etkisiz eleman) . 
s is our data's standart deviation. If with_std = False will be 1(etkisiz eleman).
'''
scaler = StandardScaler()
def df_scaler(df,name):
  '''
  Input : df - dataframe
          name - dataframe's name.
  Output : df - dataframe is scaled.
  '''
  try:
    df_scaled = scaler.fit_transform(df)
    df = pd.DataFrame(df_scaled,columns=df.columns)
    print(name,"is scaled successfully!")
  except:
    print("Exception occured step: Train Scaling!")
  return df

# %%
train_X_scaled = df_scaler(train_X,'Train')
dev_X_scaled = df_scaler(dev_X,'Dev')
test_X_scaled = df_scaler(test_X,'Test')
# Out:
# Train is scaled successfully!
# Dev is scaled successfully!
# Test is scaled successfully!

# %%
train_X
# Out:
#               date  Temperature  Humidity  Light        CO2  HumidityRatio  \
# 0     1.423072e+18     23.18000   27.2720  426.0  721.25000        0.00479
# 1     1.423072e+18     23.15000   27.2675  429.5  714.00000        0.00478
# 2     1.423072e+18     20.57617   27.2450  426.0  604.03209        0.00478
# 3     1.423072e+18     23.15000   27.2000  426.0  708.25000        0.00477
# 4     1.423072e+18     20.57617   27.2000  426.0  604.03209        0.00476
# ...            ...          ...       ...    ...        ...            ...
# 8138  1.423561e+18     21.05000   36.0975  433.0  787.25000        0.00558
# 8139  1.423561e+18     21.05000   35.9950  433.0  789.50000        0.00556
# 8140  1.423561e+18     21.10000   36.0950  433.0  798.50000        0.00560
# 8141  1.423561e+18     21.10000   36.2600  433.0  820.33333        0.00562
# 8142  1.423561e+18     21.10000   36.2000  447.0  821.00000        0.00561
#
#       Temp*Light      CO2*Temp
# 0     9874.68000  16718.575000
# 1     9942.92500  16529.100000
# 2     8765.44842  12428.666969
# 3     9861.90000  16395.987500
# 4     8765.44842  12428.666969
# ...          ...           ...
# 8138  9114.65000  16571.612500
# 8139  9114.65000  16618.975000
# 8140  9136.30000  16848.350000
# 8141  9136.30000  17309.033263
# 8142  9431.70000  17323.100000
#
# [8143 rows x 8 columns]

# %%
# Scale All Datasets.
train_X_scaled_final = df_scaler(train_X,'Train')
dev_X_scaled_final = df_scaler(dev_X,'Dev')
test_X_scaled_final = df_scaler(test_X,'Test')
# Out:
# Train is scaled successfully!
# Dev is scaled successfully!
# Test is scaled successfully!

# %%
train_ds = pd.merge(train_X_scaled_final,df_train_y,left_index=True,right_index=True)
dev_ds = pd.merge(dev_X_scaled_final,df_dev_y,left_index=True,right_index=True)
test_ds = pd.merge(test_X_scaled_final,df_test_y,left_index=True,right_index=True)

# %% [markdown]
# # 5. Data Visualization

# %%
def showAllCounts():
    df_train_counts = list(df_train[df_train.columns].count())
    df_dev_counts = list(df_dev[df_dev.columns].count())
    df_test_counts = list(df_test[df_test.columns].count())
    df_all_counts = [df_train_counts,df_dev_counts,df_test_counts]

    colNames = df_train.columns

    fig = plt.figure(figsize=(20,5))
    plt.bar(colNames,df_all_counts[0],color='c',width=0.30,label='Train',align='center')
    plt.bar(colNames,df_all_counts[1],color='m',width=0.25,label='Dev',align='edge')
    plt.bar(colNames,df_all_counts[2],color='y',width=0.15,label='Test',align='edge')
    plt.legend(loc='best')
    plt.title('Dataset Feature Counts',size=16)
    plt.xticks(size=16)
    plt.yticks(size=16)
    plt.show()

# %%
showAllCounts()

# %%
def showMissingRates():
    missing_temp = df_train.Temperature.isna().sum()
    missing_co2 = df_train.CO2.isna().sum()
    missing_counts = df_train.isna().sum()
    
    all_missing = missing_temp + missing_co2
    not_missing = len(df_train) - all_missing
    
    labels = ['Missing','Not Missing']
    data = [all_missing,not_missing]
    fig = plt.figure(figsize=(10,7))
    plt.pie(data,labels=labels,shadow=True,autopct='%1.1f%%')
    plt.title('Missing/Not Missing Rates',size=16)
    plt.show()
    
    plt.bar(df_train.columns,missing_counts)
    plt.xticks(rotation=90,size=15)
    plt.yticks(size=15)
    plt.title("Missings Counts",size=15)
    plt.show()

# %%
showMissingRates()

# %%
 '''
 Occupancy ile Feature'ların arasındaki ilişkilerin olduğu grafik.
 Mesela - CO2 - Occupancy
         Temperature - Occupancy
         ..
         ..
 '''
# Out:
# "\nOccupancy ile Feature'ların arasındaki ilişkilerin olduğu grafik.\nMesela - CO2 - Occupancy\n        Temperature - Occupancy\n        ..\n        ..\n"

# %%
train_corr = pd.merge(train_X,df_train_y,left_index=True,right_index=True).corr()
dev_corr = pd.merge(dev_X,df_dev_y,left_index=True,right_index=True).corr()
test_corr = pd.merge(test_X,df_test_y,left_index=True,right_index=True).corr()

# %%
def correlationGraph(dataset,ds_name):
    plt.figure(figsize=(12,8))
    sns.heatmap(dataset,annot=True,linewidth=.5)
    plt.title(f' Correlation of features in {ds_name} dataset', fontsize=16)

# %%
correlationGraph(train_corr,'Train')

# %%
#Correlation of dev_X-y features with each other.
correlationGraph(dev_corr,'Dev')

# %%
#Correlation of test_X- features with each other.
correlationGraph(test_corr,'Test')

# %%
def fonk(a,b):
    not_missing = df_test[(df_test[a].notnull())]
    not_missing.hist(column = a, by=b)
    plt.xlabel(a)
    plt.ylabel(b)
    plt.suptitle(a + " distribution according to room" +b)
fonk('CO2', 'Occupancy')
fonk('Temperature', 'Occupancy')
fonk('Light','Occupancy')
fonk('Humidity', 'Occupancy')
fonk('HumidityRatio', 'Occupancy')

# %% [markdown]
# ## 6. Training

# %%
X_train = train_X_scaled_final
y_train = df_train_y
X_dev = dev_X_scaled_final
y_dev = df_dev_y
X_test = test_X_scaled_final
y_test = df_test_y

opt = Adam(learning_rate=1e-6)

model = Sequential()
model.add(Dense(20,input_dim=X_train.shape[1], activation = 'relu'))
model.add(Dense(2,activation='relu'))
model.add(Dense(1,activation = 'sigmoid'))
model.compile(loss='binary_crossentropy',optimizer = opt,metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 20)                180
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 42
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 3
# =================================================================
# Total params: 225
# Trainable params: 225
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(X_train,y_train,verbose=1,epochs=200,validation_data = (X_dev,y_dev))
# Out:
# Epoch 1/200
# 255/255 [==============================] - 0s 2ms/step - loss: 0.7262 - accuracy: 0.2937 - val_loss: 0.7474 - val_accuracy: 0.2011
# Epoch 2/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.7252 - accuracy: 0.3031 - val_loss: 0.7461 - val_accuracy: 0.2015
# Epoch 3/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.7243 - accuracy: 0.3096 - val_loss: 0.7449 - val_accuracy: 0.2023
# Epoch 4/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.7233 - accuracy: 0.3161 - val_loss: 0.7436 - val_accuracy: 0.2034
# Epoch 5/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.7223 - accuracy: 0.3208 - val_loss: 0.7424 - val_accuracy: 0.2041
# Epoch 6/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.7214 - accuracy: 0.3241 - val_loss: 0.7411 - val_accuracy: 0.2045
# Epoch 7/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.7205 - accuracy: 0.3287 - val_loss: 0.7399 - val_accuracy: 0.2045
# Epoch 8/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.7195 - accuracy: 0.3316 - val_loss: 0.7386 - val_accuracy: 0.2053
# Epoch 9/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.7186 - accuracy: 0.3361 - val_loss: 0.7374 - val_accuracy: 0.2064
# Epoch 10/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.7177 - accuracy: 0.3421 - val_loss: 0.7362 - val_accuracy: 0.2064
# Epoch 11/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.7168 - accuracy: 0.3516 - val_loss: 0.7350 - val_accuracy: 0.2068
# Epoch 12/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.7159 - accuracy: 0.3604 - val_loss: 0.7338 - val_accuracy: 0.2075
# Epoch 13/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.7151 - accuracy: 0.3680 - val_loss: 0.7326 - val_accuracy: 0.2083
# Epoch 14/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.7142 - accuracy: 0.3764 - val_loss: 0.7314 - val_accuracy: 0.2090
# Epoch 15/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.7134 - accuracy: 0.3804 - val_loss: 0.7303 - val_accuracy: 0.2094
# Epoch 16/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.7126 - accuracy: 0.3884 - val_loss: 0.7291 - val_accuracy: 0.2105
# Epoch 17/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.7118 - accuracy: 0.3972 - val_loss: 0.7280 - val_accuracy: 0.2116
# Epoch 18/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.7110 - accuracy: 0.4005 - val_loss: 0.7268 - val_accuracy: 0.2124
# Epoch 19/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.7103 - accuracy: 0.4048 - val_loss: 0.7257 - val_accuracy: 0.2116
# Epoch 20/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.7095 - accuracy: 0.4096 - val_loss: 0.7246 - val_accuracy: 0.2116
# Epoch 21/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.7087 - accuracy: 0.4199 - val_loss: 0.7235 - val_accuracy: 0.2131
# Epoch 22/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.7080 - accuracy: 0.4264 - val_loss: 0.7224 - val_accuracy: 0.2139
# Epoch 23/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.7073 - accuracy: 0.4317 - val_loss: 0.7213 - val_accuracy: 0.2146
# Epoch 24/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.7065 - accuracy: 0.4378 - val_loss: 0.7202 - val_accuracy: 0.2154
# Epoch 25/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.7058 - accuracy: 0.4412 - val_loss: 0.7192 - val_accuracy: 0.2165
# Epoch 26/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.7052 - accuracy: 0.4436 - val_loss: 0.7181 - val_accuracy: 0.2169
# Epoch 27/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.7045 - accuracy: 0.4460 - val_loss: 0.7170 - val_accuracy: 0.2169
# Epoch 28/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.7038 - accuracy: 0.4498 - val_loss: 0.7160 - val_accuracy: 0.2165
# Epoch 29/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.7031 - accuracy: 0.4528 - val_loss: 0.7149 - val_accuracy: 0.2165
# Epoch 30/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.7024 - accuracy: 0.4535 - val_loss: 0.7139 - val_accuracy: 0.2173
# Epoch 31/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.7017 - accuracy: 0.4546 - val_loss: 0.7128 - val_accuracy: 0.2180
# Epoch 32/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.7011 - accuracy: 0.4555 - val_loss: 0.7117 - val_accuracy: 0.2191
# Epoch 33/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.7004 - accuracy: 0.4570 - val_loss: 0.7107 - val_accuracy: 0.2248
# Epoch 34/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6997 - accuracy: 0.4586 - val_loss: 0.7096 - val_accuracy: 0.2379
# Epoch 35/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6990 - accuracy: 0.4633 - val_loss: 0.7085 - val_accuracy: 0.2589
# Epoch 36/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6984 - accuracy: 0.4656 - val_loss: 0.7075 - val_accuracy: 0.2724
# Epoch 37/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6977 - accuracy: 0.4766 - val_loss: 0.7065 - val_accuracy: 0.2916
# Epoch 38/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6971 - accuracy: 0.4982 - val_loss: 0.7055 - val_accuracy: 0.3009
# Epoch 39/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6964 - accuracy: 0.5040 - val_loss: 0.7045 - val_accuracy: 0.3129
# Epoch 40/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6958 - accuracy: 0.5076 - val_loss: 0.7037 - val_accuracy: 0.3189
# Epoch 41/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6953 - accuracy: 0.5122 - val_loss: 0.7030 - val_accuracy: 0.3220
# Epoch 42/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6947 - accuracy: 0.5189 - val_loss: 0.7022 - val_accuracy: 0.3325
# Epoch 43/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6942 - accuracy: 0.5236 - val_loss: 0.7015 - val_accuracy: 0.3448
# Epoch 44/200
# 255/255 [==============================] - 0s 2ms/step - loss: 0.6936 - accuracy: 0.5381 - val_loss: 0.7007 - val_accuracy: 0.3568
# Epoch 45/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6931 - accuracy: 0.5633 - val_loss: 0.7000 - val_accuracy: 0.3647
# Epoch 46/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6926 - accuracy: 0.5843 - val_loss: 0.6993 - val_accuracy: 0.3771
# Epoch 47/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6921 - accuracy: 0.6020 - val_loss: 0.6986 - val_accuracy: 0.3869
# Epoch 48/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6916 - accuracy: 0.6216 - val_loss: 0.6980 - val_accuracy: 0.3977
# Epoch 49/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6912 - accuracy: 0.6369 - val_loss: 0.6974 - val_accuracy: 0.4109
# Epoch 50/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6908 - accuracy: 0.6490 - val_loss: 0.6968 - val_accuracy: 0.4176
# Epoch 51/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6904 - accuracy: 0.6612 - val_loss: 0.6963 - val_accuracy: 0.4248
# Epoch 52/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6901 - accuracy: 0.6681 - val_loss: 0.6958 - val_accuracy: 0.4293
# Epoch 53/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6898 - accuracy: 0.6737 - val_loss: 0.6953 - val_accuracy: 0.4330
# Epoch 54/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6895 - accuracy: 0.6780 - val_loss: 0.6949 - val_accuracy: 0.4379
# Epoch 55/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6892 - accuracy: 0.6819 - val_loss: 0.6945 - val_accuracy: 0.4405
# Epoch 56/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6889 - accuracy: 0.6844 - val_loss: 0.6941 - val_accuracy: 0.4443
# Epoch 57/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6886 - accuracy: 0.6876 - val_loss: 0.6937 - val_accuracy: 0.4488
# Epoch 58/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6884 - accuracy: 0.6913 - val_loss: 0.6933 - val_accuracy: 0.4537
# Epoch 59/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6881 - accuracy: 0.6946 - val_loss: 0.6929 - val_accuracy: 0.4608
# Epoch 60/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6878 - accuracy: 0.6969 - val_loss: 0.6925 - val_accuracy: 0.4642
# Epoch 61/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6876 - accuracy: 0.6986 - val_loss: 0.6921 - val_accuracy: 0.4698
# Epoch 62/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6873 - accuracy: 0.7023 - val_loss: 0.6917 - val_accuracy: 0.4765
# Epoch 63/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6870 - accuracy: 0.7056 - val_loss: 0.6913 - val_accuracy: 0.4803
# Epoch 64/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6868 - accuracy: 0.7098 - val_loss: 0.6909 - val_accuracy: 0.4848
# Epoch 65/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6865 - accuracy: 0.7136 - val_loss: 0.6905 - val_accuracy: 0.4916
# Epoch 66/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6863 - accuracy: 0.7182 - val_loss: 0.6901 - val_accuracy: 0.4987
# Epoch 67/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6860 - accuracy: 0.7216 - val_loss: 0.6897 - val_accuracy: 0.5077
# Epoch 68/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6857 - accuracy: 0.7268 - val_loss: 0.6893 - val_accuracy: 0.5133
# Epoch 69/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6855 - accuracy: 0.7315 - val_loss: 0.6889 - val_accuracy: 0.5171
# Epoch 70/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6853 - accuracy: 0.7377 - val_loss: 0.6885 - val_accuracy: 0.5216
# Epoch 71/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6850 - accuracy: 0.7462 - val_loss: 0.6881 - val_accuracy: 0.5246
# Epoch 72/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6848 - accuracy: 0.7516 - val_loss: 0.6877 - val_accuracy: 0.5332
# Epoch 73/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6845 - accuracy: 0.7571 - val_loss: 0.6873 - val_accuracy: 0.5343
# Epoch 74/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6843 - accuracy: 0.7624 - val_loss: 0.6870 - val_accuracy: 0.5358
# Epoch 75/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6841 - accuracy: 0.7656 - val_loss: 0.6866 - val_accuracy: 0.5377
# Epoch 76/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6838 - accuracy: 0.7669 - val_loss: 0.6862 - val_accuracy: 0.5392
# Epoch 77/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6836 - accuracy: 0.7695 - val_loss: 0.6859 - val_accuracy: 0.5418
# Epoch 78/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6834 - accuracy: 0.7710 - val_loss: 0.6855 - val_accuracy: 0.5426
# Epoch 79/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6831 - accuracy: 0.7724 - val_loss: 0.6851 - val_accuracy: 0.5430
# Epoch 80/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6829 - accuracy: 0.7754 - val_loss: 0.6848 - val_accuracy: 0.5452
# Epoch 81/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6827 - accuracy: 0.7780 - val_loss: 0.6844 - val_accuracy: 0.5460
# Epoch 82/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6824 - accuracy: 0.7802 - val_loss: 0.6841 - val_accuracy: 0.5475
# Epoch 83/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6822 - accuracy: 0.7826 - val_loss: 0.6837 - val_accuracy: 0.5512
# Epoch 84/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6820 - accuracy: 0.7878 - val_loss: 0.6833 - val_accuracy: 0.5535
# Epoch 85/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6818 - accuracy: 0.7927 - val_loss: 0.6830 - val_accuracy: 0.5550
# Epoch 86/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6815 - accuracy: 0.7958 - val_loss: 0.6826 - val_accuracy: 0.5583
# Epoch 87/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6813 - accuracy: 0.7972 - val_loss: 0.6822 - val_accuracy: 0.5610
# Epoch 88/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6810 - accuracy: 0.7980 - val_loss: 0.6818 - val_accuracy: 0.5640
# Epoch 89/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6808 - accuracy: 0.7990 - val_loss: 0.6814 - val_accuracy: 0.5662
# Epoch 90/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6805 - accuracy: 0.8006 - val_loss: 0.6810 - val_accuracy: 0.5689
# Epoch 91/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6803 - accuracy: 0.8027 - val_loss: 0.6806 - val_accuracy: 0.5711
# Epoch 92/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6800 - accuracy: 0.8039 - val_loss: 0.6802 - val_accuracy: 0.5737
# Epoch 93/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6798 - accuracy: 0.8056 - val_loss: 0.6798 - val_accuracy: 0.5745
# Epoch 94/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6795 - accuracy: 0.8088 - val_loss: 0.6794 - val_accuracy: 0.5771
# Epoch 95/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6793 - accuracy: 0.8104 - val_loss: 0.6790 - val_accuracy: 0.5790
# Epoch 96/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6790 - accuracy: 0.8124 - val_loss: 0.6786 - val_accuracy: 0.5816
# Epoch 97/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6787 - accuracy: 0.8132 - val_loss: 0.6782 - val_accuracy: 0.5846
# Epoch 98/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6785 - accuracy: 0.8144 - val_loss: 0.6778 - val_accuracy: 0.5854
# Epoch 99/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6782 - accuracy: 0.8148 - val_loss: 0.6774 - val_accuracy: 0.5865
# Epoch 100/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6779 - accuracy: 0.8158 - val_loss: 0.6769 - val_accuracy: 0.5876
# Epoch 101/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6776 - accuracy: 0.8170 - val_loss: 0.6765 - val_accuracy: 0.5884
# Epoch 102/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6774 - accuracy: 0.8178 - val_loss: 0.6761 - val_accuracy: 0.5884
# Epoch 103/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6771 - accuracy: 0.8184 - val_loss: 0.6756 - val_accuracy: 0.5887
# Epoch 104/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6768 - accuracy: 0.8190 - val_loss: 0.6751 - val_accuracy: 0.5899
# Epoch 105/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6765 - accuracy: 0.8203 - val_loss: 0.6747 - val_accuracy: 0.5902
# Epoch 106/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6763 - accuracy: 0.8232 - val_loss: 0.6742 - val_accuracy: 0.5917
# Epoch 107/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6760 - accuracy: 0.8257 - val_loss: 0.6737 - val_accuracy: 0.5940
# Epoch 108/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6757 - accuracy: 0.8277 - val_loss: 0.6732 - val_accuracy: 0.5974
# Epoch 109/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6754 - accuracy: 0.8299 - val_loss: 0.6727 - val_accuracy: 0.6000
# Epoch 110/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6751 - accuracy: 0.8315 - val_loss: 0.6723 - val_accuracy: 0.6023
# Epoch 111/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6748 - accuracy: 0.8325 - val_loss: 0.6718 - val_accuracy: 0.6030
# Epoch 112/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6745 - accuracy: 0.8338 - val_loss: 0.6713 - val_accuracy: 0.6056
# Epoch 113/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6742 - accuracy: 0.8354 - val_loss: 0.6708 - val_accuracy: 0.6064
# Epoch 114/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6739 - accuracy: 0.8361 - val_loss: 0.6703 - val_accuracy: 0.6075
# Epoch 115/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6736 - accuracy: 0.8370 - val_loss: 0.6698 - val_accuracy: 0.6083
# Epoch 116/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6733 - accuracy: 0.8375 - val_loss: 0.6693 - val_accuracy: 0.6101
# Epoch 117/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6730 - accuracy: 0.8390 - val_loss: 0.6688 - val_accuracy: 0.6131
# Epoch 118/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6727 - accuracy: 0.8402 - val_loss: 0.6683 - val_accuracy: 0.6285
# Epoch 119/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6724 - accuracy: 0.8413 - val_loss: 0.6678 - val_accuracy: 0.6675
# Epoch 120/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6720 - accuracy: 0.8429 - val_loss: 0.6673 - val_accuracy: 0.7032
# Epoch 121/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6717 - accuracy: 0.8432 - val_loss: 0.6667 - val_accuracy: 0.7287
# Epoch 122/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6714 - accuracy: 0.8440 - val_loss: 0.6662 - val_accuracy: 0.7388
# Epoch 123/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6710 - accuracy: 0.8456 - val_loss: 0.6657 - val_accuracy: 0.7550
# Epoch 124/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6706 - accuracy: 0.8474 - val_loss: 0.6651 - val_accuracy: 0.7647
# Epoch 125/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6702 - accuracy: 0.8504 - val_loss: 0.6645 - val_accuracy: 0.7782
# Epoch 126/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6698 - accuracy: 0.8530 - val_loss: 0.6640 - val_accuracy: 0.7850
# Epoch 127/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6694 - accuracy: 0.8556 - val_loss: 0.6634 - val_accuracy: 0.7944
# Epoch 128/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6690 - accuracy: 0.8584 - val_loss: 0.6628 - val_accuracy: 0.7989
# Epoch 129/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6685 - accuracy: 0.8632 - val_loss: 0.6622 - val_accuracy: 0.8011
# Epoch 130/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6681 - accuracy: 0.8669 - val_loss: 0.6617 - val_accuracy: 0.8045
# Epoch 131/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6677 - accuracy: 0.8681 - val_loss: 0.6611 - val_accuracy: 0.8064
# Epoch 132/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6672 - accuracy: 0.8701 - val_loss: 0.6606 - val_accuracy: 0.8075
# Epoch 133/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6668 - accuracy: 0.8733 - val_loss: 0.6600 - val_accuracy: 0.8083
# Epoch 134/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6664 - accuracy: 0.8751 - val_loss: 0.6594 - val_accuracy: 0.8094
# Epoch 135/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6659 - accuracy: 0.8763 - val_loss: 0.6589 - val_accuracy: 0.8094
# Epoch 136/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6655 - accuracy: 0.8777 - val_loss: 0.6583 - val_accuracy: 0.8105
# Epoch 137/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6651 - accuracy: 0.8784 - val_loss: 0.6578 - val_accuracy: 0.8120
# Epoch 138/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6647 - accuracy: 0.8790 - val_loss: 0.6573 - val_accuracy: 0.8135
# Epoch 139/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6643 - accuracy: 0.8793 - val_loss: 0.6568 - val_accuracy: 0.8143
# Epoch 140/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6639 - accuracy: 0.8798 - val_loss: 0.6563 - val_accuracy: 0.8161
# Epoch 141/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6634 - accuracy: 0.8803 - val_loss: 0.6558 - val_accuracy: 0.8173
# Epoch 142/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6630 - accuracy: 0.8803 - val_loss: 0.6553 - val_accuracy: 0.8180
# Epoch 143/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6626 - accuracy: 0.8806 - val_loss: 0.6548 - val_accuracy: 0.8195
# Epoch 144/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6622 - accuracy: 0.8809 - val_loss: 0.6543 - val_accuracy: 0.8236
# Epoch 145/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6618 - accuracy: 0.8812 - val_loss: 0.6539 - val_accuracy: 0.8255
# Epoch 146/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6614 - accuracy: 0.8811 - val_loss: 0.6534 - val_accuracy: 0.8274
# Epoch 147/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6610 - accuracy: 0.8814 - val_loss: 0.6529 - val_accuracy: 0.8300
# Epoch 148/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6606 - accuracy: 0.8814 - val_loss: 0.6524 - val_accuracy: 0.8319
# Epoch 149/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6602 - accuracy: 0.8817 - val_loss: 0.6519 - val_accuracy: 0.8341
# Epoch 150/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6598 - accuracy: 0.8819 - val_loss: 0.6514 - val_accuracy: 0.8368
# Epoch 151/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6594 - accuracy: 0.8830 - val_loss: 0.6509 - val_accuracy: 0.8394
# Epoch 152/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6590 - accuracy: 0.8830 - val_loss: 0.6504 - val_accuracy: 0.8417
# Epoch 153/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6586 - accuracy: 0.8830 - val_loss: 0.6499 - val_accuracy: 0.8435
# Epoch 154/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6582 - accuracy: 0.8833 - val_loss: 0.6494 - val_accuracy: 0.8454
# Epoch 155/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6578 - accuracy: 0.8836 - val_loss: 0.6489 - val_accuracy: 0.8477
# Epoch 156/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6574 - accuracy: 0.8835 - val_loss: 0.6484 - val_accuracy: 0.8503
# Epoch 157/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6570 - accuracy: 0.8842 - val_loss: 0.6479 - val_accuracy: 0.8533
# Epoch 158/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6566 - accuracy: 0.8842 - val_loss: 0.6474 - val_accuracy: 0.8555
# Epoch 159/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6561 - accuracy: 0.8847 - val_loss: 0.6469 - val_accuracy: 0.8600
# Epoch 160/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6557 - accuracy: 0.8853 - val_loss: 0.6464 - val_accuracy: 0.8634
# Epoch 161/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6553 - accuracy: 0.8858 - val_loss: 0.6459 - val_accuracy: 0.8653
# Epoch 162/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6549 - accuracy: 0.8859 - val_loss: 0.6454 - val_accuracy: 0.8660
# Epoch 163/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6545 - accuracy: 0.8867 - val_loss: 0.6449 - val_accuracy: 0.8687
# Epoch 164/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6541 - accuracy: 0.8868 - val_loss: 0.6445 - val_accuracy: 0.8690
# Epoch 165/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6537 - accuracy: 0.8879 - val_loss: 0.6440 - val_accuracy: 0.8717
# Epoch 166/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6533 - accuracy: 0.8881 - val_loss: 0.6435 - val_accuracy: 0.8735
# Epoch 167/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6529 - accuracy: 0.8887 - val_loss: 0.6430 - val_accuracy: 0.8747
# Epoch 168/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6525 - accuracy: 0.8894 - val_loss: 0.6425 - val_accuracy: 0.8750
# Epoch 169/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6521 - accuracy: 0.8900 - val_loss: 0.6420 - val_accuracy: 0.8758
# Epoch 170/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6517 - accuracy: 0.8902 - val_loss: 0.6415 - val_accuracy: 0.8762
# Epoch 171/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6513 - accuracy: 0.8908 - val_loss: 0.6411 - val_accuracy: 0.8803
# Epoch 172/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6509 - accuracy: 0.8914 - val_loss: 0.6406 - val_accuracy: 0.8811
# Epoch 173/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6505 - accuracy: 0.8916 - val_loss: 0.6401 - val_accuracy: 0.8818
# Epoch 174/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6501 - accuracy: 0.8918 - val_loss: 0.6396 - val_accuracy: 0.8826
# Epoch 175/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6497 - accuracy: 0.8919 - val_loss: 0.6391 - val_accuracy: 0.8841
# Epoch 176/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6493 - accuracy: 0.8921 - val_loss: 0.6386 - val_accuracy: 0.8841
# Epoch 177/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6489 - accuracy: 0.8923 - val_loss: 0.6381 - val_accuracy: 0.8856
# Epoch 178/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6485 - accuracy: 0.8928 - val_loss: 0.6376 - val_accuracy: 0.8867
# Epoch 179/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6481 - accuracy: 0.8932 - val_loss: 0.6371 - val_accuracy: 0.8886
# Epoch 180/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6477 - accuracy: 0.8932 - val_loss: 0.6367 - val_accuracy: 0.8919
# Epoch 181/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6473 - accuracy: 0.8933 - val_loss: 0.6362 - val_accuracy: 0.8949
# Epoch 182/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6469 - accuracy: 0.8934 - val_loss: 0.6357 - val_accuracy: 0.8994
# Epoch 183/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6465 - accuracy: 0.8937 - val_loss: 0.6352 - val_accuracy: 0.9043
# Epoch 184/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6461 - accuracy: 0.8941 - val_loss: 0.6347 - val_accuracy: 0.9077
# Epoch 185/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6458 - accuracy: 0.8941 - val_loss: 0.6342 - val_accuracy: 0.9099
# Epoch 186/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6454 - accuracy: 0.8944 - val_loss: 0.6337 - val_accuracy: 0.9122
# Epoch 187/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6450 - accuracy: 0.8944 - val_loss: 0.6332 - val_accuracy: 0.9137
# Epoch 188/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6446 - accuracy: 0.8946 - val_loss: 0.6327 - val_accuracy: 0.9152
# Epoch 189/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6442 - accuracy: 0.8948 - val_loss: 0.6322 - val_accuracy: 0.9174
# Epoch 190/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6438 - accuracy: 0.8949 - val_loss: 0.6317 - val_accuracy: 0.9205
# Epoch 191/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6435 - accuracy: 0.8949 - val_loss: 0.6312 - val_accuracy: 0.9231
# Epoch 192/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6431 - accuracy: 0.8949 - val_loss: 0.6307 - val_accuracy: 0.9231
# Epoch 193/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6427 - accuracy: 0.8949 - val_loss: 0.6302 - val_accuracy: 0.9238
# Epoch 194/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6423 - accuracy: 0.8950 - val_loss: 0.6297 - val_accuracy: 0.9242
# Epoch 195/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6420 - accuracy: 0.8950 - val_loss: 0.6292 - val_accuracy: 0.9242
# Epoch 196/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6416 - accuracy: 0.8954 - val_loss: 0.6288 - val_accuracy: 0.9250
# Epoch 197/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6412 - accuracy: 0.8954 - val_loss: 0.6283 - val_accuracy: 0.9253
# Epoch 198/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6409 - accuracy: 0.8956 - val_loss: 0.6278 - val_accuracy: 0.9257
# Epoch 199/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6405 - accuracy: 0.8961 - val_loss: 0.6273 - val_accuracy: 0.9261
# Epoch 200/200
# 255/255 [==============================] - 0s 1ms/step - loss: 0.6401 - accuracy: 0.8961 - val_loss: 0.6268 - val_accuracy: 0.9265

# %%
hist_test = model.evaluate(X_test,y_test) # accuracy on test set
# Out:
# 305/305 [==============================] - 0s 709us/step - loss: 0.6469 - accuracy: 0.9242

# %%
fig,ax = plt.subplots(1,2)
fig.set_size_inches(15, 7)
ax[0].plot(history.history['loss'],label='Train')
ax[0].plot(history.history['val_loss'],label='Validation')
ax[0].set_title('Loss Graph')
ax[0].set_xlabel('Epoch')
ax[0].legend(loc='best')

ax[1].plot(history.history['accuracy'],label='Train')
ax[1].plot(history.history['val_accuracy'],label='Validation')
ax[1].set_title('Accuracy Graph')
ax[1].set_xlabel('Epoch')
ax[1].legend(loc='best')

# %%
model.save('mymodel.h5')
